# %%
# Snapshot governance data analysis and visualization

# %%
# Load 'cerebrumdao_snapshot_proposals.csv' dataframe

import pandas as pd

df = pd.read_csv('cerebrumdao_snapshot_proposals.csv')
df.head()
# Out:
#                                                   id  \
# 0  0xd9b7956d5c4e581663406f8229f305e4956b4da8ab2e...
# 1  0x1127ca0bbabbc459e2cb234fa7c8d4193c3ac961ac53...
# 2  0xc4e8ec238f91f142a91e4b8edf4b05d1c398b083dba5...
# 3  0xb84180deb65bd9aa1bd0514e96c8f272c5458f3eded2...
# 4  0xa1b478c6199d3e157e2db7124f2f789b59ee314974f2...
#
#                                    title  \
# 0          CDP-17: [Funding] SK-Channels
# 1            CDP-16: Treasury Management
# 2          CDP-15 - OTC Funding Proposal
# 3       CDP-14: [Funding] Fission Pharma
# 4  CDP-13: [Funding] Arctic Therapeutics
#
#                                                 body  \
# 0  _One liner: The SK -channel project is develop...
# 1  # Summary\n\nCerebrum DAO has been operating p...
# 2  Cerebrum DAO has been approached by multiple p...
# 3  ***__One liner:__** Fission Pharma is developi...
# 4  ***One liner:*** *Arctic Therapeutics is accel...
#
#                          choices                start                  end  \
# 0  ['For', 'Against', 'Abstain']  2025-05-01 23:04:04  2025-05-06 23:04:04
# 1  ['For', 'Against', 'Abstain']  2024-12-29 15:37:08  2025-01-03 15:37:08
# 2  ['For', 'Against', 'Abstain']  2024-12-19 22:52:09  2024-12-24 22:52:09
# 3  ['For', 'Against', 'Abstain']  2024-11-13 23:23:50  2024-11-18 23:23:50
# 4  ['For', 'Against', 'Abstain']  2024-10-23 20:49:37  2024-10-28 20:49:37
#
#     state                                      author              created  \
# 0  closed  0xeEd06591f929895b27752F690e970BcCBe963f66  2025-05-01 21:04:04
# 1  closed  0xeEd06591f929895b27752F690e970BcCBe963f66  2024-12-29 13:37:08
# 2  closed  0xeEd06591f929895b27752F690e970BcCBe963f66  2024-12-19 20:52:09
# 3  closed  0xeEd06591f929895b27752F690e970BcCBe963f66  2024-11-13 21:23:50
# 4  closed  0xeEd06591f929895b27752F690e970BcCBe963f66  2024-10-23 18:49:37
#
#                                        scores  scores_total  votes
# 0                   [9471106026.245836, 0, 0]  9.471106e+09     12
# 1                   [6639917944.794216, 0, 0]  6.639918e+09     16
# 2                   [8085663111.249771, 0, 0]  8.085663e+09     14
# 3  [7410542234.999247, 0, 138055935.22282475]  7.548598e+09     14
# 4                   [8955337920.012995, 0, 0]  8.955338e+09     12

# %%
# Basic data overview

print("Number of proposals:", len(df))
print("Date range:", df['created'].min(), "to", df['created'].max())
print("Columns:", df.columns.tolist())
# Out:
# Number of proposals: 17
# Date range: 2024-04-23 14:17:08 to 2025-05-01 21:04:04
# Columns: ['id', 'title', 'body', 'choices', 'start', 'end', 'state', 'author', 'created', 'scores', 'scores_total', 'votes']

# %%
# Make sure you have a Datetime value

df['created'] = pd.to_datetime(df['created'], errors='coerce')
print(df['created'].dtype)

# confirm is datetime64[ns]
# Out:
# datetime64[ns]

# %%
# KPI 1 — Proposal Activity Over Time
# SEE BELOW FOR A PLOT WITH MONTHS WITH NO ACTIVITY
#> A healthy DAO should have regular proposals. Plot proposals per month.

df['month'] = df['created'].dt.to_period('M')
proposals_per_month = df.groupby('month').size()

import matplotlib.pyplot as plt

proposals_per_month.plot(kind='bar', figsize=(10,4), title='Proposals per Month')
plt.ylabel('Number of Proposals')
plt.xlabel('Month')

plt.savefig('SnapshotProposalsMonth.png', dpi=300, bbox_inches='tight')  # Use fig.savefig, OR plt.savefig if not subplotted
plt.show()

# %%
# INTERPRETATION: 1) Are proposals frequent or sporadic? 2)Is activity increasing, steady, or declining?

# Activity seems steady since inception 2024.
# Peak activity Jan 2025 aligned with bigger movement of tokens from Etherscan and launch on Base

# %%
# KPI 2 — Voter Participation
#> High participation = engaged community. Plot number of voters per proposal.

df = df.sort_values('created')
plt.figure(figsize=(10,4))
plt.plot(df['created'], df['votes'], marker='o')
plt.title('Voter Participation per Proposal')
plt.xlabel('Proposal Date')
plt.ylabel('Number of Voters')

plt.savefig('SnapshotVoterParticipation.png', dpi=300, bbox_inches='tight')  # Use fig.savefig, OR plt.savefig if not subplotted
plt.show()

# %%
# Interpretation: 1) Are most proposals getting votes? 2) Any trends (up/down/flat)?

# the number of votes declined in July 2024 and is steadily low.
# The community engagement on Snaphot seems to have declined steadily

# %%
# KPI 3 — Proposal Outcomes
#> Shows if proposals are being decided and executed.
#> Count proposals by state. ALL PROPOSALS CLOSED

print(df['state'].value_counts())
df['state'].value_counts().plot(kind='bar', title='Proposal States')
plt.ylabel('Number of Proposals')
plt.show()
# Out:
# state
# closed    17
# Name: count, dtype: int64

# %%
# Interpretation: 1) Are most proposals closed/executed, or left open? 2) Are decisions being made?

# all proposals are closed, decisions are being made

# %%
# KPI 4 — Voting Power Distribution
#> Shows if a few whales dominate, or if voting is decentralized.
#> Look at scores (votes per choice) and scores_total (total voting power).

# %%
plt.figure(figsize=(10,4))
plt.hist(df['scores_total'], bins=20)
plt.title('Distribution of Total Voting Power per Proposal')
plt.xlabel('Total Voting Power')
plt.ylabel('Number of Proposals')

plt.savefig('SnapshotVoterParticipation.png', dpi=300, bbox_inches='tight')  # Use fig.savefig, OR plt.savefig if not subplotted
plt.show()

# %%
#Interpretation: 1) Are some proposals dominated by huge voting power? 2) Are there proposals with very little participation?

# some proposals seem dominated by bigger voting power

# %%
# KPI 5 — Proposal Topics (Optional, for Deeper Analysis)
#> Shows if proposals align with the DAO’s mission (e.g., neuroscience funding, research, community building).
#> Look at the title and body columns.

# use keyword searches or word clouds for a quick overview.

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp313-cp313-macosx_10_13_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from wordcloud) (2.2.4)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from wordcloud) (11.2.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from wordcloud) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from matplotlib->wordcloud) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/cerebrum_env/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp313-cp313-macosx_10_13_x86_64.whl (172 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
import wordcloud
from wordcloud import WordCloud

text = ' '.join(df['title'].dropna().tolist())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in Proposal Titles')

plt.show()

# %%
print(df['title'].unique()[:10])  # See a sample of titles

# they all start with CDP lets filter out
# Out:
# ['CDP-1 [Governance] - Cerebrum DAO Governance Framework v1'
#  'CDP-2 [Funding] - Fission Pharma'
#  'CDP-3 [Funding} - Post TGE Auction OTC Funding'
#  'CDP-4 Adding DEX Support for NEURON'
#  'CDP-5 Creating a Product Working Group'
#  'CDP-6 OTC Funding and Liquidity Support with BoostVC'
#  'CDP-7: Bridge NEURON to Base and Create a Liquidity Pool on Aerodrome Finance'
#  "CDP-8: Transfidelity for protein stability in Alzheimer's disease"
#  'CDP-9: Governance Framework V1.2 - Implementation of a Soft Governance Mechanism'
#  'CDP-10: Cerebrum DAO Compensation Policy']

# %%
# filter out CDP as possible result in wordcloud

import re

text = ' '.join(df['title'].dropna().tolist())
text = re.sub(r'\bcdp\b', '', text, flags=re.IGNORECASE)

from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in Proposal Titles (Excluding "CDP")')

plt.savefig('SnapshotWordCloud.png', dpi=300, bbox_inches='tight')  # Use fig.savefig, OR plt.savefig if not subplotted
plt.show()

# %%
import re
from collections import Counter

# Combine all titles, remove "CDP" (case-insensitive)
text = ' '.join(df['title'].dropna().tolist())
text = re.sub(r'\bcdp\b', '', text, flags=re.IGNORECASE)

# Remove punctuation and split into words
words = re.findall(r'\b\w+\b', text.lower())

# Count word frequencies
word_counts = Counter(words)

# List the top 10 words
top_10 = word_counts.most_common(10)
print("Top 10 words (excluding 'CDP'):")
for word, count in top_10:
    print(f"{word}: {count}")
# Out:
# Top 10 words (excluding 'CDP'):
# funding: 8
# governance: 4
# otc: 3
# a: 3
# product: 3
# cerebrum: 2
# dao: 2
# framework: 2
# v1: 2
# 2: 2

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Ensure 'created' is datetime
df['created'] = pd.to_datetime(df['created'])

# Create a complete range of months from the min to max date
all_months = pd.period_range(df['created'].min().to_period('M'), df['created'].max().to_period('M'), freq='M')

# Assign month period to each row
df['month'] = df['created'].dt.to_period('M')

# Count proposals per month
proposals_per_month = df.groupby('month').size().reindex(all_months, fill_value=0)

# Plot bar chart
fig, ax = plt.subplots(figsize=(12, 5))
proposals_per_month.plot(kind='bar', ax=ax, color='skyblue', label='Proposals per Month')

# Add trend line (linear regression)
x = np.arange(len(proposals_per_month))
y = proposals_per_month.values
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
ax.plot(x, p(x), "r--", label='Trend')

# Formatting
ax.set_title('Proposals per Month')
ax.set_ylabel('Number of Proposals')
ax.set_xlabel('Month')
ax.set_xticks(x)
ax.set_xticklabels([str(m) for m in proposals_per_month.index], rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.savefig('SnapshotProposalsMonth.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Interpretation: 1) Are proposals about neuroscience, research, funding, etc.? 2) Or are they off-topic?

# it seems that the proposals are mainly admin/management. none of the top 10 words in neuroscience related

# It seems that the governance requires mainly admin stuff and this causes a decrease in community engagement

# %%
#Step 9: Synthesize Findings
#Are proposals frequent and relevant?
#Is the community engaged in voting?
#Is voting power decentralized?
#Are proposals being decided and executed?
#Do proposal topics align with the mission?


#Step 10: Next Steps
#If you want to analyze individual votes (who voted, how much), you can fetch votes for each proposal using the Snapshot API.
#Combine these findings with your on-chain analysis for a holistic view.
